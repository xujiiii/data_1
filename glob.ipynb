# %%
import glob


print(glob.glob('data/data/infla*.csv'))
# Out:
# ['data/data\\inflammation-01.csv', 'data/data\\inflammation-02.csv', 'data/data\\inflammation-03.csv', 'data/data\\inflammation-04.csv', 'data/data\\inflammation-05.csv', 'data/data\\inflammation-06.csv', 'data/data\\inflammation-07.csv', 'data/data\\inflammation-08.csv', 'data/data\\inflammation-09.csv', 'data/data\\inflammation-10.csv', 'data/data\\inflammation-11.csv', 'data/data\\inflammation-12.csv']

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt

filenames=glob.glob('data/data/infla*.csv')
filenames.sort(reverse=False)
filenames=filenames[0:3]
for filename in filenames:
    print(filename)
    data=np.loadtxt(filename,delimiter=',')

    fig=plt.plot(np.mean(data,axis=0))
    plt.show()
# Out:
# data/data\inflammation-01.csv
# data/data\inflammation-02.csv
# data/data\inflammation-03.csv

# %%
if 8 <7:
    print('really?')
else:
    print('yeah')
# Out:
# yeah
